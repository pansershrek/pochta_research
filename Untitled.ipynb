# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import json

# %%
data = pd.read_excel("./data/Батч 1.xlsx")
for i in range(2, 6):
    data = data.append(pd.read_excel("./data/Батч {}.xlsx".format(i)), ignore_index=True)

# %%
# здесь нет бандеролей
del data["бандероль"]
del data["с объявл. ценностью"]
del data["с налож. платежом"]

# %%
data['сумма ОЦ (руб)'].fillna(0, inplace=True)
data['сумма НП (руб)'].fillna(0, inplace=True)
data["отметка 'Осторожно'"].fillna(False, inplace=True)

# %%
data.head()
# Out:
#                                     hid             дата оформления  \
# 0  17279630-2e29-4a0d-8f96-f3c932e6bbcb  2020-07-05 00:00:26.036000
# 1  16971e43-728a-4f66-a93c-3678aa8433cd  2020-07-05 00:03:17.229000
# 2  16d739fa-ca72-4b12-b8a1-ae5d91df945f  2020-07-05 00:11:47.671000
# 3                               8182829  2020-07-05 00:12:50.965000
# 4  1645b790-f6f9-4c3f-b92b-eae34e781784  2020-07-05 00:13:05.474000
#
#    индекс отправителя  индекс получателя  вес (гр)  стоимость (руб,коп)  \
# 0              109469             107241     100.0                173.0
# 1              390039             125284    1100.0                238.0
# 2              111250             670033     100.0                173.0
# 3              105173             183035    2262.0                363.0
# 4              195197             184209    1905.0                338.0
#
#    сумма ОЦ (руб)  сумма НП (руб)  безбланковая отправка ускоренное  \
# 0             0.0             0.0                  False       True
# 1             0.0             0.0                   True      False
# 2             0.0             0.0                   True       True
# 3             0.0             0.0                  False      False
# 4             0.0             0.0                  False      False
#
#    международное с описью вложений  отметка 'Осторожно' sms для отправителя  \
# 0          False             False                False               False
# 1          False             False                False               False
# 2          False             False                False               False
# 3          False             False                False               False
# 4          False             False                False               False
#
#   sms для получателя
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %%
def append_region_id(data, index_column):
    # определяем почтовый район -- первые 3 цифры индекса
    res = data.copy()
    res["район {}".format(index_column.split()[1])] = [str(x)[:3] for x in res[index_column]]
    return res

# %%
def split_databases(data):
    # попытка определить из какой базы строка
    res = data.copy()
    res["secondDB"] = [isinstance(x, int) for x in res["hid"]]
    return res

# %%
def add_region_and_city_name(data):
    # получаем названия города и региона по индексу
    res = data.copy()
    with open('data/p2a.json', encoding='utf8') as f:
        p2a = json.load(f)
    
    for point in ['отправителя', 'получателя']:
        res['регион {}'.format(point)] = [p2a.get(x)['region']
                                          if p2a.get(x) else str(x)[:3]
                                          for x in res['индекс {}'.format(point)].astype(str)]
        res['город {}'.format(point)] = [(
                                    else p2a.get(x)['subregion']
                                    if 'subregion' in p2a.get(x)
                                    p2a.get(x)['locality']
                                    if 'locality' in p2a.get(x)
                                    else p2a.get(x)['region'])
                                    if p2a.get(x) else str(x)[:3]
                                    for x in res['индекс {}'.format(point)].astype(str)]
        
        res.dropna(subset=['город {}'.format(point)], inplace=True)
    return res
# Out:
#   File "<ipython-input-237-defb29246a26>", line 12
#     else p2a.get(x)['subregion']
#        ^
# SyntaxError: invalid syntax

# %%
new_data = append_region_id(data, "индекс отправителя")
new_data = append_region_id(new_data, "индекс получателя")
new_data = split_databases(new_data)

new_data_regions = add_region_and_city_name(new_data)

# %%
cnts_sends = cnts_per_user.value_counts()
cnts_send_filtered = cnts_sends
# cnts_send_filtered.plot(kind='bar', figsize=(25, 10))
cnts_per_user = new_data['hid'].value_counts()

# сколько пользователей обеспечивают T часть оборота
T = 0.75

res = 0.0
cnt_p = 0
for k in cnts_send_filtered.keys()[-1::-1]:
    res += k * cnts_send_filtered[k]
    cnt_p += cnts_send_filtered[k]
    if res/new_data.shape[0] > T:
        break
        
print(cnt_p)
# Out:
# 9717

# %%
# Распределение весов
new_data['вес (гр)'].value_counts().plot(kind='hist', figsize=(25, 10), bins=500)

# %%
with open("cities_send.txt", "w", encoding='utf8') as f:
    f.write(new_data_regions['город отправителя'].value_counts().to_string())
with open("cities_get.txt", "w", encoding='utf8') as f:
    f.write(new_data_regions['город получателя'].value_counts().to_string())

# %%
new_data.groupby('hid').agg(["max", "mean", "min"])
# Out:
#                                      индекс отправителя                    \
#                                                     max      mean     min
# hid
# 300950                                           192019  192019.0  192019
# 345420                                           111401  111401.0  111401
# 345660                                           390044  390044.0  390044
# 345914                                           660098  660098.0  660098
# 345920                                           156026  156026.0  156026
# ...                                                 ...       ...     ...
# 1739f767-078e-4f37-9d63-5ef1bcc20d04             655009  655009.0  655009
# 1739f7cc-c33a-4623-9950-1ca38998f1af             630099  630099.0  630099
# 1739f7d1-7057-4124-9dd0-1ee8823806ec             187114  187114.0  187114
# 1739f7e3-fc34-4c75-a728-e3db2a41121c             603135  603135.0  603135
# 1739f8b3-d46c-4747-b7f1-09d93d649c27             357506  357506.0  357506
#
#                                      индекс получателя                         \
#                                                    max           mean     min
# hid
# 300950                                          683002  351687.526316  123308
# 345420                                          295047  295047.000000  295047
# 345660                                          694454  407610.217949  109542
# 345914                                          440015  440015.000000  440015
# 345920                                          665903  665903.000000  665903
# ...                                                ...            ...     ...
# 1739f767-078e-4f37-9d63-5ef1bcc20d04            666904  666904.000000  666904
# 1739f7cc-c33a-4623-9950-1ca38998f1af            620135  620135.000000  620135
# 1739f7d1-7057-4124-9dd0-1ee8823806ec            108850  108850.000000  108850
# 1739f7e3-fc34-4c75-a728-e3db2a41121c            693012  693012.000000  693012
# 1739f8b3-d46c-4747-b7f1-09d93d649c27            350018  350018.000000  350018
#
#                                      вес (гр)                         \
#                                           max          mean      min
# hid
# 300950                                 1120.0    330.526316    150.0
# 345420                                  190.0    190.000000    190.0
# 345660                                 3000.0    263.076923    100.0
# 345914                                   65.0     65.000000     65.0
# 345920                                  300.0    300.000000    300.0
# ...                                       ...           ...      ...
# 1739f767-078e-4f37-9d63-5ef1bcc20d04  15000.0  15000.000000  15000.0
# 1739f7cc-c33a-4623-9950-1ca38998f1af    379.0    379.000000    379.0
# 1739f7d1-7057-4124-9dd0-1ee8823806ec   4500.0   4500.000000   4500.0
# 1739f7e3-fc34-4c75-a728-e3db2a41121c    500.0    500.000000    500.0
# 1739f8b3-d46c-4747-b7f1-09d93d649c27    300.0    300.000000    300.0
#
#                                      стоимость (руб,коп)  ... сумма НП (руб)  \
#                                                      max  ...            min
# hid                                                       ...
# 300950                                             455.0  ...            NaN
# 345420                                             230.0  ...            NaN
# 345660                                             658.0  ...          336.0
# 345914                                             179.0  ...            NaN
# 345920                                             356.2  ...            NaN
# ...                                                  ...  ...            ...
# 1739f767-078e-4f37-9d63-5ef1bcc20d04              2443.2  ...            NaN
# 1739f7cc-c33a-4623-9950-1ca38998f1af               264.0  ...            NaN
# 1739f7d1-7057-4124-9dd0-1ee8823806ec               463.0  ...            NaN
# 1739f7e3-fc34-4c75-a728-e3db2a41121c               334.0  ...            NaN
# 1739f8b3-d46c-4747-b7f1-09d93d649c27               334.0  ...            NaN
#
#                                      безбланковая отправка              \
#                                                        max mean    min
# hid
# 300950                                                True  1.0   True
# 345420                                               False  0.0  False
# 345660                                                True  1.0   True
# 345914                                                True  1.0   True
# 345920                                               False  0.0  False
# ...                                                    ...  ...    ...
# 1739f767-078e-4f37-9d63-5ef1bcc20d04                 False  0.0  False
# 1739f7cc-c33a-4623-9950-1ca38998f1af                  True  1.0   True
# 1739f7d1-7057-4124-9dd0-1ee8823806ec                  True  1.0   True
# 1739f7e3-fc34-4c75-a728-e3db2a41121c                  True  1.0   True
# 1739f8b3-d46c-4747-b7f1-09d93d649c27                  True  1.0   True
#
#                                      международное               secondDB  \
#                                                max   mean    min      max
# hid
# 300950                                       False  False  False     True
# 345420                                       False  False  False     True
# 345660                                       False  False  False     True
# 345914                                       False  False  False     True
# 345920                                       False  False  False     True
# ...                                            ...    ...    ...      ...
# 1739f767-078e-4f37-9d63-5ef1bcc20d04         False  False  False    False
# 1739f7cc-c33a-4623-9950-1ca38998f1af         False  False  False    False
# 1739f7d1-7057-4124-9dd0-1ee8823806ec         False  False  False    False
# 1739f7e3-fc34-4c75-a728-e3db2a41121c         False  False  False    False
# 1739f8b3-d46c-4747-b7f1-09d93d649c27         False  False  False    False
#
#
#                                        mean    min
# hid
# 300950                                 True   True
# 345420                                 True   True
# 345660                                 True   True
# 345914                                 True   True
# 345920                                 True   True
# ...                                     ...    ...
# 1739f767-078e-4f37-9d63-5ef1bcc20d04  False  False
# 1739f7cc-c33a-4623-9950-1ca38998f1af  False  False
# 1739f7d1-7057-4124-9dd0-1ee8823806ec  False  False
# 1739f7e3-fc34-4c75-a728-e3db2a41121c  False  False
# 1739f8b3-d46c-4747-b7f1-09d93d649c27  False  False
#
# [62173 rows x 27 columns]
